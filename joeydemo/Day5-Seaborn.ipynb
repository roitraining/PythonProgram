# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mp
import matplotlib.pyplot as plt

ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

#plt.plot(ts)
ts.plot()

# %%
ts.plot()

# %%
plt.plot(ts)

# %%
np.random.seed(0)
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

df = DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))
#['A','B','C','D']
#df = DataFrame(np.random.randn(1000,4), index=ts.index, columns='Alpha,Beta,Gamma,Delta'.split(','))
df = df.cumsum()
#display(df)
#display(df)
#df.loc[:,['A','B']].plot()
#plt.plot(df)
df.plot()

# %%
a = np.random.randn(1000)-1
b = np.random.randn(1000)
#c = np.random.randn(1000)+1
c = a / 2
df = pd.DataFrame({'A':a, 'B': b, 'C':c})
#display(df)
df[['A','B']].plot(kind='hist', alpha = .6)

# %%
#df = pd.DataFrame({'A': a, 'B': b})
df.hist(alpha = .3)

# %%
#display(df)
plt.scatter(df['A'], df['B'])

# %%
pd.plotting.scatter_matrix(df, alpha = .3, diagonal = 'kde')

#help(pd.plotting.scatter_matrix)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb62c9cc7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb6291e9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb629211f60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb6291c0518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb629167a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb629199048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb62913f5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb6290e9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb6290e9ba8>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df, diagonal = 'kde', alpha = .3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb62ab15048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb629017438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb628fbe908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb628f65e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb628f97438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb628f3f9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb628ee6f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb628f18518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb628f18550>]],
#       dtype=object)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
#display(iris)
ax = sns.catplot(x = 'species', y = 'sepal_width', data = iris, kind = 'strip')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'swarm')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'box')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'violin')

# %% [markdown]
# ## LAB 3: ##
#
# ### 1. Try the catplot with the following values for kind: point, bar & boxen
# ### 2. Try customizing the colors using the palette parameter and the sns.color_palette function
#
# <br>
# <details><summary>Click for <b>hint</b></summary>
# <p>
# palette = sns.color_palette(['green', 'red', 'yellow'])
# <br>
# <br>
# </p>
# </details>
#
#
# <details><summary>Click for <b>code</b></summary>
# <p>
#
# ```python
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'point')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'bar')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = sns.color_palette(['green', 'red', 'yellow']))
# ```
# </p>
# </details>

# %%
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'point') 
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'bar') 
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = ['green', 'red', 'yellow']) 
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = sns.color_palette([(0,.9,1), (1,0,0), (1,1,0)]))
