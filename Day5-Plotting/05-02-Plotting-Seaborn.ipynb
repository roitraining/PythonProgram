# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mp
import matplotlib.pyplot as plt

ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

#plt.plot(ts)
ts.plot()

# %%
ts.plot()

# %%
plt.plot(ts)

# %%
np.random.seed(0)
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

df = DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))
#['A','B','C','D']
#df = DataFrame(np.random.randn(1000,4), index=ts.index, columns='Alpha,Beta,Gamma,Delta'.split(','))
df = df.cumsum()
#display(df)
df.loc[:,['A','B']].plot()
#plt.plot(df)

# %%
a = np.random.randn(1000)-1
b = np.random.randn(1000)
c = np.random.randn(1000)+1
df = pd.DataFrame({'A':a, 'B': b, 'C':c})
#display(df)
df.plot(kind='hist')

# %%
#df = pd.DataFrame({'A': a, 'B': b})
df.hist(alpha = .3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9eb0d2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9eacf400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9eaf5978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ea9eef0>]],
#       dtype=object)

# %%
#display(df)
plt.scatter(df['A'], df['B'])

# %%
pd.plotting.scatter_matrix(df, alpha = .3, diagonal = 'kde')

#help(pd.plotting.scatter_matrix)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9e9e7cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9cf105f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9cf36ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9cee8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ce8d5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ceb5b70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ce64128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ce0d6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9ce0d710>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df, diagonal = 'kde', alpha = .3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c97391780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c973b0d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c973602e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c97309780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c97330cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c972e22b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c97289828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c972b4dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c972b4e10>]],
#       dtype=object)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'strip')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'swarm')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'box')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'violin')

# %% [markdown]
# ## LAB 3: ##
#
# ### 1. Try the catplot with the following values for kind: point, bar & boxen
# ### 2. Try customizing the colors using the palette parameter and the sns.color_palette function
#
# <br>
# <details><summary>Click for <b>hint</b></summary>
# <p>
# palette = sns.color_palette(['green', 'red', 'yellow'])
# <br>
# <br>
# </p>
# </details>
#
#
# <details><summary>Click for <b>code</b></summary>
# <p>
#
# ```python
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'point')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'bar')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = sns.color_palette(['green', 'red', 'yellow']))
# ```
# </p>
# </details>

# %%
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'point') 
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'bar') 
#ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = ['green', 'red', 'yellow']) 
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = sns.color_palette([(0,.9,1), (1,0,0), (1,1,0)]))
