# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

ts.plot()

# %%
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

df = DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))

df = df.cumsum()

df.plot()

# %%
a = np.random.randn(1000)-1
b = np.random.randn(1000)
c = np.random.randn(1000)+1
df = pd.DataFrame({'A': a})
df.plot(kind='hist')

# %%
df = pd.DataFrame({'A': a, 'B': b})
df.plot(kind='hist')

# %%
pd.plotting.scatter_matrix(df, alpha = .3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c8a135c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c89d7470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c817e9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c8126f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c81584e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c80fda58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c80a4fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c80d75c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c80d75f8>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df, diagonal = 'kde', alpha = .3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2f71710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2f1a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2ec19e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2ee8f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2e99518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2e40a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2e73048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2e1c5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53c2e1c630>]],
#       dtype=object)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'strip')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'swarm')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'box')

# %%
ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'violin')

# %% [markdown]
# ## LAB 3: ##
#
# ### 1. Try the catplot with the following values for kind: point, bar & boxen
# ### 2. Try customizing the colors using the palette parameter and the sns.color_palette function
#
# <br>
# <details><summary>Click for <b>hint</b></summary>
# <p>
# palette = sns.color_palette(['green', 'red', 'yellow'])
# <br>
# <br>
# </p>
# </details>
#
#
# <details><summary>Click for <b>code</b></summary>
# <p>
#
# ```python
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'point')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'bar')
# ax = sns.catplot(x = 'species', y = 'sepal_length', data = iris, kind = 'boxen', palette = sns.color_palette(['green', 'red', 'yellow']))
# ```
# </p>
# </details>
